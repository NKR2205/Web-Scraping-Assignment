# %% [markdown]
# # Web Scraping Exception Handling Selenium

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException
from selenium.webdriver.common.by import  By
import time
import requests

# %%
# Connecting to the driver
driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %% [markdown]
# # Q1. Python program to search product in amazon - Guitar

# %%
# Opening Amazon Page
driver.get("http://www.amazon.in/")

# %%
# Entering Designation and Location
product = driver.find_element(By.XPATH,'//input[@id="twotabsearchtextbox"]')
product.send_keys('guitar')

# %%
search = driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
search.click()

# %% [markdown]
# # Q2. Python program to search product in amazon - Guitar details

# %%
# Scraping Product URL

prod_url = []

for page in range(0,3):
    url = driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url[0:48]:
        prod_url.append(i.get_attribute("href"))
    nxt_button = driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    nxt_button.click()
    time.sleep(2)

# %%
len(prod_url)
# Out:
# 144

# %%
prod_url
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTozODc1NTMwNzg1ODk1MjYzOjE2NzE4NjY0NzA6c3BfYXRmOjIwMDU3MTkzMDU2MjA0OjowOjo&url=%2FKadence-Slowhand-Premium-Acoustic-Instrument%2Fdp%2FB077SZ667X%2Fref%3Dsr_1_1_sspa%3Fcrid%3D1EYDAMC8E2HQU%26keywords%3Dguitar%26qid%3D1671866470%26sprefix%3Dguitar%252Caps%252C549%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTozODc1NTMwNzg1ODk1MjYzOjE2NzE4NjY0NzA6c3BfYXRmOjIwMDk2NjA4NzUwNDk4OjowOjo&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_2_sspa%3Fcrid%3D1EYDAMC8E2HQU%26keywords%3Dguitar%26qid%3D1671866470%26sprefix%3Dguitar%252Caps%252C549%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26smid%3DAM04Z7MH4HSDD',
# ...

# %%
Brand = []

for url in prod_url[0:144]:
    driver.get(url)
    time.sleep(2)
    
    try:
        brand = driver.find_element(By.XPATH,'//*[@id="productOverview_feature_div"]/div/table/tbody/tr[1]/td[2]/span')
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')

# %%
len(Brand)
# Out:
# 144

# %%
Brand
# Out:
# ['Kadence',
#  'Kadence',
#  'Wooden',
#  'multi-coloured',
#  'Juârez',
#  'Intern',
#  'Intern',
#  'Intern',
#  'Intern',
#  'JUAREZ',
#  'Intern',
#  'HOVNER',
#  'Intern',
#  'YAMAHA',
#  'Fender',
#  'YAMAHA',
#  'HOVNER',
#  'Kadence',
#  'Intern',
#  'Kadence',
#  'Kadence',
#  'Medellin',
#  'JUAREZ',
#  'JUAREZ',
#  'blueberry',
#  'Multicolor',
#  'blueberry',
#  'FESTRA',
#  'Kadence',
#  'Intern',
#  'YAMAHA',
#  'JUAREZ',
#  'JUAREZ',
#  'Medellin',
#  'Juârez',
#  'Intern',
#  'Medellin',
#  'Juârez',
#  'JUAREZ',
#  'Intern',
#  'Intern',
#  'Intern',
#  'YAMAHA',
#  'JUAREZ',
#  'Schecter',
#  'REVEL',
#  'Intern',
#  'YAMAHA',
#  'blueberry',
#  'Guitar Bro',
#  'Cort',
#  'blueberry',
#  'JUAREZ',
#  'Intern',
#  'Fender',
#  'Fender',
#  'Fender',
#  'YAMAHA',
#  'YAMAHA',
#  'YAMAHA',
#  'Medellin',
#  'Ibanez',
#  'JUAREZ',
#  'Kadence',
#  'YAMAHA',
#  'Kadence',
#  'Shanrya',
#  'Pluto',
#  'HOVNER',
#  'Kadence',
#  'Fender',
#  'VAULT',
#  'blueberry',
# ...

# %%
name_prod = []

for name in prod_url[0:144]:
    driver.get(name)
    time.sleep(2)
    
    try:
        prod_name = driver.find_element(By.XPATH,'//span[@class="a-size-large product-title-word-break"]')
        name_prod.append(prod_name.text)
    except NoSuchElementException:
        name_prod.append('-')

# %%
len(name_prod)
# Out:
# 144

# %%
name_prod
# Out:
# ['Kadence Slowhand Premium Jumbo Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo (Black Spruce Wood)',
#  'Kadence Frontier guitar with Online Guitar learning course , Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'VD ENTERPRISE String Acoustic Guitar | Adjustable Tunning Knob | Classical Guitar Toy | Musical Instrument Learning Toy for Kids',
#  "Hontral S4 String Decor Guitar Children's Musical Instrument Educational Toy Small Guitar for Beginners Kids Child - 23Inch",
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Right hand Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black, small',
#  'Intern INT-38C Acoustic Guitar Kit (Blue)',
#  'Intern 38C Ebony Wood Cutaway Design Acoustic Guitar with Picks And Carry Bag (Black)',
# ...

# %%
price = []

for rate in prod_url[0:144]:
    driver.get(rate)
    time.sleep(2)
    
    try:
        price_rate = driver.find_element(By.XPATH,'//span[@class="a-price-whole"]')
        price.append(price_rate.text)
    except NoSuchElementException:
        price.append('-')

# %%
len(price)
# Out:
# 144

# %%
price
# Out:
# ['9,900',
#  '4,949',
#  '799',
#  '899',
#  '2,149',
#  '2,129',
#  '2,399',
#  '2,099',
#  '2,299',
#  '2,440',
#  '2,399',
#  '4,480',
#  '2,099',
#  '7,490',
#  '12,499',
#  '9,990',
#  '4,480',
#  '6,998',
#  '2,099',
#  '4,998',
#  '5,498',
#  '2,428',
#  '2,479',
#  '2,759',
#  '2,515',
#  '479',
#  '4,990',
#  '4,495',
#  '5,397',
#  '2,499',
#  '8,699',
#  '2,749',
#  '2,600',
#  '2,428',
#  '3,339',
#  '2,499',
#  '2,428',
#  '6,329',
#  '2,109',
#  '2,390',
#  '2,390',
#  '2,390',
#  '8,799',
#  '2,739',
#  '25,499',
#  '2,914',
#  '2,399',
#  '9,990',
#  '2,655',
#  '8,999',
#  '10,800',
#  '4,495',
#  '5,749',
#  '3,590',
#  '12,531',
#  '7,132',
#  '11,799',
#  '7,590',
#  '7,590',
#  '7,590',
#  '2,247',
#  '6,990',
#  '2,570',
#  '9,898',
#  '9,760',
#  '4,998',
#  '1,511',
#  '6,057',
#  '4,750',
#  '6,298',
#  '14,490',
#  '4,465',
#  '2,795',
#  '4,495',
#  '10,299',
#  '2,755',
#  '21,039',
#  '9,295',
#  '7,600',
#  '6,698',
#  '2,399',
#  '10,570',
#  '10,570',
# ...

# %%
return_x = []

for return1 in prod_url[0:144]:
    driver.get(return1)
    time.sleep(3)
    
    try:
        retx = driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]/span/div[2]/a')
        return_x.append(retx.text)
    except NoSuchElementException:
        return_x.append('-')

# %%
len(return_x)
# Out:
# 144

# %%
return_x
# Out:
# ['7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
#  '7 days Replacement',
# ...

# %%
delivery = []

for delv in prod_url[0:144]:
    driver.get(delv)
    time.sleep(2)
    
    try:
        deli = driver.find_element(By.XPATH,'//*[@id="mir-layout-DELIVERY_BLOCK"]')
        delivery.append(deli.text)
    except NoSuchElementException:
        delivery.append('-')

# %%
len(delivery)
# Out:
# 144

# %%
delivery
# Out:
# ['FREE delivery Thursday, 29 December. Details\nOr fastest delivery Monday, 26 December. Order within 1 hr 31 mins. Details',
#  'FREE delivery Monday, 26 December. Details\nOr fastest delivery Tomorrow, December 25. Order within 8 hrs 35 mins. Details',
#  'FREE delivery Wednesday, 28 December. Details\nOr fastest delivery Tuesday, 27 December. Details',
#  'FREE delivery Wednesday, 28 December. Details\nOr fastest delivery Tuesday, 27 December. Details',
#  'FREE delivery Monday, 26 December. Details\nOr fastest delivery Tomorrow, December 25. Order within 8 hrs 50 mins. Details',
#  'FREE delivery Monday, 26 December. Details\nOr fastest delivery Tomorrow, December 25. Order within 8 hrs 50 mins. Details',
#  'FREE delivery Monday, 26 December. Details\nOr fastest delivery Tomorrow, December 25. Order within 8 hrs 50 mins. Details',
#  'FREE delivery Monday, 26 December. Details\nOr fastest delivery Tomorrow, December 25. Order within 8 hrs 50 mins. Details',
# ...

# %%
len(delivery)
# Out:
# 174

# %%
avail1 = []

for ava in prod_url[0:144]:
    driver.get(ava)
    time.sleep(2)
    
    try:
        aval = driver.find_element(By.XPATH,'//*[@id="availability"]/span')
        avail1.append(aval.text)
    except NoSuchElementException:
        avail1.append('-')

# %%
len(avail1)
# Out:
# 144

# %%
avail1
# Out:
# ['',
#  '',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'Only 1 left in stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
#  'Only 1 left in stock (more on the way).',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'Only 1 left in stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'Usually dispatched in 1 to 2 months.',
#  'Only 2 left in stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
# ...

# %%
df = pd.DataFrame({"Brand Name":Brand,"Name of the Product":name_prod,"Price":price,"Return/Exchange":return_x,"Expected Delivery":delivery,"Availability":avail1,"Product URL":prod_url})
df
# Out:
#          Brand Name                                Name of the Product  \
# 0           Kadence  Kadence Slowhand Premium Jumbo Semi Acoustic G...
# 1           Kadence  Kadence Frontier guitar with Online Guitar lea...
# 2            Wooden  VD ENTERPRISE String Acoustic Guitar | Adjusta...
# 3    multi-coloured  Hontral S4 String Decor Guitar Children's Musi...
# 4            Juârez  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
# ..              ...                                                ...
# 139          YAMAHA  Yamaha FSX80C Semi acoustic cutaway guitar (Bl...
# 140        Epiphone  Epiphone Slash J-45 Acoustic Electric Guitar -...
# 141     PRS Guitars  PRS Guitars Electric Guitar, SE Standard 245, ...
# 142     PRS Guitars  PRS Guitars Electric Guitar, SE Custom 24, 202...
# 143         Kadence  Kadence AstroMan Electric Guitar, 21 FRETS, RO...
#
#         Price     Return/Exchange  \
# 0       9,900  7 days Replacement
# 1       4,949  7 days Replacement
# ...

# %%
df.to_csv('Guitar.csv')

# %%
pd.read_csv('Guitar.csv')
# Out:
#      Unnamed: 0      Brand Name  \
# 0             0         Kadence
# 1             1         Kadence
# 2             2          Wooden
# 3             3  multi-coloured
# 4             4          Juârez
# ..          ...             ...
# 139         139          YAMAHA
# 140         140        Epiphone
# 141         141     PRS Guitars
# 142         142     PRS Guitars
# 143         143         Kadence
#
#                                    Name of the Product     Price  \
# 0    Kadence Slowhand Premium Jumbo Semi Acoustic G...     9,900
# 1    Kadence Frontier guitar with Online Guitar lea...     4,949
# 2    VD ENTERPRISE String Acoustic Guitar | Adjusta...       799
# 3    Hontral S4 String Decor Guitar Children's Musi...       899
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...     2,149
# ..                                                 ...       ...
# 139  Yamaha FSX80C Semi acoustic cutaway guitar (Bl...    12,570
# ...

# %% [markdown]
# # Q3. Scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’

# %% [markdown]
# Q3.A. Cakes

# %%
# Connecting to the driver
driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Connecting to the webpage

driver.get("https://images.google.com/")

# %%
# Searching for cakes

item = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
item.send_keys("Cakes")

# %%
search = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search.click()

# %%
img_url = []

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_url.append(source)

# %%
img_url
# Out:
# ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQk1Ca9GGek1tOi5ckXImJHJQGu_THFXThMAA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVwzYvlLk5KC3NEskBIiKjM_1RVBbCDM25qA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTjwgJ60SExrC8W58b43Iw6yqLA9wmqWQM2bA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRR80yYU1ljug4tet4NYzjk4sBPo3uMYGCw1g&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSp61J_OzcfxlU6Ku3cy0rbMET9PPQDcCn30w&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSFZfXtRGjkZh6Vu0omULKJ9r5SPAQanwJvnQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6w1fHQtrZ3SZL7WXq_xgTDjDFI9pS1Pn_Lw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCXCg3gEdzu_u4lvmeV6OKMwABLPG5jbjxuA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRo9CLul7IHBGxIr0VZMD4oNJW3M7CupXrUKQ&usqp=CAU',
# ...

# %%
len(img_url)
# Out:
# 10

# %%
import requests

# %%
img_data=[]

for i in range(len(img_url)):
    if i > 10:
        break
    print("Downloading {0} of {1} images" .format(i,10))
    response = requests.get(img_url[i])
    file = open(r"C:\Users\navee\Desktop\Data Science Course Materials\FlipRobo Onboarding - 112022\Assignment\Images"+str(i)+",.jpg","wb")
    file.write(response.content)

# %% [markdown]
# Q3.B. Fruits

# %%
# Connecting to the webpage

driver.get("https://images.google.com/")

# %%
# Searching for cakes

item = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
item.send_keys("Fruits")

# %%
search = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")

fruits_url = []

fruits = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for fruit in fruits:
    source = fruit.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            fruits_url.append(source)

# %%
fruits_data=[]

for i in range(len(fruits_url)):
    if i > 10:
        break
    print("Downloading {0} of {1} images" .format(i,10))
    response = requests.get(fruits_url[i])
    file = open(r"C:\Users\navee\Desktop\Data Science Course Materials\FlipRobo Onboarding - 112022\Assignment\fruits\Images"+str(i)+",.jpg","wb")
    file.write(response.content)

# %% [markdown]
# Q3.C. Cars

# %%
# Connecting to the webpage

driver.get("https://images.google.com/")

# %%
#Searching for cars

item = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
item.send_keys("Cars")

# %%
#Searching for cars

search = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
    
cars_url = []

cars = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for car in cars:
    source = car.get_attribute('src')
    if source is not None:
        if (source[0:4] == 'http'):
            cars_url.append(source)

# %%
cars_data = []

for i in range(len(cars_url)):
    if i > 10:
        break
    print("Downloading {0} of {1} images" .format(i,10))
    response = requests.get(cars_url[i])
    file = open(r"C:\Users\navee\Desktop\Data Science Course Materials\FlipRobo Onboarding - 112022\Assignment\Cars\Images" +str(i)+".jpg","wb")
    file.write(response.content)

# %% [markdown]
# #Q3.D. Guitar

# %%
# Connecting to driver

driver.get("https://images.google.com/")

# %%
#searching for Guitar

item = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
item.send_keys("Guitar")

# %%
#searching for Guitar

search = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search.click()

# %%
for _ in range(0,20):
    driver.execute_script("window.scrollBy(0,1000)")

guitar_url = []

guitars = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for guitar in guitars:
    source = guitar.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            guitar_url.append(source)
            
guitar_data = []

for i in range(len(guitar_url)):
    if i > 10:
        break
    print("Downloading image {0} of {1}" .format(i,10))
    response = requests.get(guitar_url[i])
    file = open(r"C:\Users\navee\Desktop\Data Science Course Materials\FlipRobo Onboarding - 112022\Assignment\Guitar\Images"+str(i)+ ".jpg","wb")
    file.write(response.content)

# %% [markdown]
# Q3.E. Machine Learning

# %%
# Connecting to the driver
driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Connecting to driver

driver.get("https://images.google.com/")

# %%
# Searching for Machinr learning

item = driver.find_element(By.XPATH,'//input[@class="gLFyf"]')
item.send_keys("Machine Learning")

# %%
# Searching for Machinr learning

search = driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search.click()

# %%
for _ in range(0,20):
    driver.execute_script("window.scrollBy(0,1000)")
    
macl_url = []

machine = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

for mac in machine:
    source = mac.get_attribute('src')
    if source is not None:
         if(source[0:4] =='http'):
                macl_url.append(source)

for i in range(len(macl_url)):
    if i > 10:
        break
    print("Downloading {0} of {1} images" .format(i,10))
    response = requests.get(macl_url[i])
    file = open(r"C:\Users\navee\Desktop\Data Science Course Materials\FlipRobo Onboarding - 112022\Assignment\Machine Learning\Images"+str(i)+ ".jpg","wb")
    file.write(response.content)

# %% [markdown]
# # Q4. Python Program to search for a Smartphone

# %%
#connecting to driver

driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# opening webpage

driver.get("http://www.flipkart.com/")

# %%
# searching for smartphones

item = driver.find_element(By.XPATH,'//input[@class="_3704LK"]')
item.send_keys("Oneplus Nord")

# %%
search = driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
# Scraping URL and Smartphone Name

ph = []

url = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for phone in url:
    ph.append(phone.get_attribute('href'))
    
smart = []

for name in ph[0:24]:
    driver.get(name)
    time.sleep(2)
    
    try:
        smart1 = driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        smart.append(smart1.text)
    except NoSuchException:
        smart.append('-')

# %%
ph
# Out:
# ['https://www.flipkart.com/oneplus-nord-ce-2-lite-5g-blue-tide-128-gb/p/itm7acae55b999e6?pid=MOBGJMUHHJE55ARU&lid=LSTMOBGJMUHHJE55ARUZ9R98L&marketplace=FLIPKART&q=Oneplus+Nord&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=35467013-94f6-4f56-9942-d019e3090991.MOBGJMUHHJE55ARU.SEARCH&ppt=hp&ppn=homepage&ssid=ijk507cd6o0000001671945401697&qH=53863d4d978d5074',
#  'https://www.flipkart.com/oneplus-nord-ce-2-lite-5g-blue-tide-128-gb/p/itm7acae55b999e6?pid=MOBGKGRADDHG3PN4&lid=LSTMOBGKGRADDHG3PN4EVYXS2&marketplace=FLIPKART&q=Oneplus+Nord&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=35467013-94f6-4f56-9942-d019e3090991.MOBGKGRADDHG3PN4.SEARCH&ppt=hp&ppn=homepage&ssid=ijk507cd6o0000001671945401697&qH=53863d4d978d5074',
# ...

# %%
smart
# Out:
# ['OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord 2T 5G (Jade Fog, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord CE 2 Lite (Black Dusk, 128 MB)  (6 GB RAM)',
#  'OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)  (8 GB RAM)',
#  'OnePlus Nord CE 5G (Charcoal Ink, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord 2 5G (PAC-MAN, 256 GB)  (12 GB RAM)',
#  'OnePlus Nord 2T 5G (Jade Fog, 256 GB)  (12 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord 2 5G (Gray Sierra, 256 GB)  (12 GB RAM)',
#  'OnePlus Nord 2 5G (Green Wood, 256 GB)  (12 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  (6 GB RAM)',
#  'OnePlus Nord 2 5G (Gray Sierra, 128 GB)  (8 GB RAM)',
# ...

# %%
# Scraping URL and Smartphone Name

ph = []

url = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for phone in url:
    ph.append(phone.get_attribute('href'))
    
smart = []

for name in ph[0:24]:
    driver.get(name)
    time.sleep(2)
    
    try:
        smart1 = driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        smart.append(smart1.text)
    except NoSuchException:
        smart.append('-')

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import  By
import time
import requests

# %%
#scraping colour

colour = []

for col in ph[0:24]:
    driver.get(col)
    time.sleep(2)
    
    try:
        col1 = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        colour.append(col1.text)
    except NoSuchElementException:
        smart.append('-')

# %%
colour
# Out:
# ['Blue Tide',
#  'Blue Tide',
#  'Blue Tide',
#  'Jade Fog',
#  'Black Dusk',
#  'Black Dusk',
#  'Bahama Blue',
#  'Charcoal Ink',
#  'PAC-MAN',
#  'Jade Fog',
#  'Black Dusk',
#  'Gray Sierra',
#  'Green Wood',
#  'Blue Tide',
#  'Black Dusk',
#  'Gray Sierra',
#  'Gray Shadow',
#  'Gray Shadow',
#  'Gray Shadow',
#  'Jade Fog',
#  'Gray Onyx',
#  'Gray Onyx',
#  'Gray Onyx',
#  'Blue Marble']

# %%
#scraping RAM

ram = []

for ram1 in ph[0:24]:
    driver.get(ram1)
    time.sleep(2)
    
    try:
        read = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        read.click()
        ram2 = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[2]/td[2]/ul/li')
        ram.append(ram2.text)
    except NoSuchElementException:
        ram.append('-')

# %%
ram
# Out:
# ['6 GB',
#  '6 GB',
#  '6 GB',
#  '8 GB',
#  '6 GB',
#  '6 GB',
#  '8 GB',
#  '6 GB',
#  '12 GB',
#  '12 GB',
#  '6 GB',
#  '12 GB',
#  '12 GB',
#  '6 GB',
#  '6 GB',
#  '8 GB',
#  '12 GB',
#  '12 GB',
#  '8 GB',
#  '12 GB',
#  '6 GB',
#  '12 GB',
#  '8 GB',
#  '12 GB']

# %%
#scraping Storage(ROM)

storage = []

for rom in ph[0:24]:
    driver.get(rom)
    time.sleep(2)
    
    try:
        read = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        read.click()
        rom2 = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        storage.append(rom2.text)
    except NoSuchElementException:
        storage.append('-')

# %%
storage
# Out:
# ['128 GB',
#  '128 GB',
#  '128 GB',
#  '128 GB',
#  '128 GB',
#  '128 MB',
#  '128 GB',
#  '128 GB',
#  '256 GB',
#  '256 GB',
#  '128 GB',
#  '256 GB',
#  '256 GB',
#  '128 GB',
#  '128 GB',
#  '128 GB',
#  '256 GB',
#  '256 GB',
#  '128 GB',
#  '256 GB',
#  '64 GB',
#  '256 GB',
#  '128 GB',
#  '256 GB']

# %%
#scraping Primary/Secondary Camera

p_cam = []

for cam in ph[0:24]:
    driver.get(cam)
    time.sleep(2)
    
    try:
        read = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        read.click()
        camera = driver.find_element(By.XPATH,'//div[@class="_2cM9lP"]/div[2]/ul/li[3]')
        p_cam.append(camera.text)
    except NoSuchElementException:
        p_cam.append('-')

# %%
p_cam
# Out:
# ['64MP Rear Camera',
#  '64MP Rear Camera',
#  '64MP Rear Camera',
#  '50MP Rear Camera',
#  '64MP Rear Camera',
#  '64MP Rear Camera',
#  '64MP Rear Camera',
#  '64MP Rear Camera',
#  '50MP Rear Camera',
#  '50MP Rear Camera',
#  '64MP Rear Camera',
#  '50MP Rear Camera',
#  '50MP Rear Camera',
#  '64MP Rear Camera | 16MP Front Camera',
#  '64MP Rear Camera',
#  '50MP Rear Camera',
#  '50MP Rear Camera',
#  '50MP Rear Camera',
#  '50MP Rear Camera',
#  '50MP Rear Camera',
#  '48MP + 8MP | 32MP + 8MP Dual Front Camera',
#  '48MP + 8MP | 32MP + 8MP Dual Front Camera',
#  '48MP + 8MP | 32MP + 8MP Dual Front Camera',
#  '48MP + 8MP | 32MP + 8MP Dual Front Camera']

# %%
#scraping Display

display = []

for size in ph[0:24]:
    driver.get(size)
    time.sleep(2)
    
    try:
        size2 = driver.find_element(By.XPATH,'//div[@class="_2cM9lP"]/div[2]/ul/li[2]')
        display.append(size2.text)
    except NoSuchElementException:
        display.append('-')

# %%
display
# Out:
# ['16.74 cm (6.59 inch) Display',
#  '16.74 cm (6.59 inch) Display',
#  '16.74 cm (6.59 inch) Display',
#  '17.02 cm (6.7 inch) Display',
#  '16.74 cm (6.59 inch) Display',
#  '16.74 cm (6.59 inch) Display',
#  '16.33 cm (6.43 inch) Display',
#  '16.33 cm (6.43 inch) Display',
#  '16.33 cm (6.43 inch) Display',
#  '17.02 cm (6.7 inch) Display',
#  '16.74 cm (6.59 inch) Display',
#  '16.33 cm (6.43 inch) Display',
#  '16.33 cm (6.43 inch) Display',
#  '16.74 cm (6.59 inch) HD+ Display',
#  '16.74 cm (6.59 inch) Display',
#  '16.33 cm (6.43 inch) Display',
#  '16.94 cm (6.67 inch) Display',
#  '17.02 cm (6.7 inch) Display',
#  '17.02 cm (6.7 inch) Display',
#  '17.02 cm (6.7 inch) Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display',
#  '16.36 cm (6.44 inch) Full HD+ Display']

# %%
# Scraping Battery Size

battery = []

for bat in ph[0:24]:
    driver.get(bat)
    time.sleep(2)
    
    try:
        bat2 = driver.find_element(By.XPATH,'//div[@class="_2cM9lP"]/div[2]/ul/li[4]')
        battery.append(bat2.text)
        
    except NoSuchElementException:
        battery.append('-')

# %%
battery
# Out:
# ['5000 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '4500 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '5000 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '5000 mAh Battery',
#  '5000 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '4500 mAh Battery',
#  '4115 mAh Battery',
#  '4115 mAh Battery',
#  '4115 mAh Battery',
#  '4115 mAh Battery']

# %%
# Scraping Price

price = []

for amt in ph[0:24]:
    driver.get(amt)
    time.sleep(2)
    
    try:
        amt2 = driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        price.append(amt2.text)
        
    except NoSuchElementException:
        price.append('-')

# %%
price
# Out:
# ['₹19,875',
#  '₹19,949',
#  '₹19,950',
#  '₹28,999',
#  '₹19,890',
#  '₹19,885',
#  '₹24,998',
#  '₹20,899',
#  '₹37,990',
#  '₹33,999',
#  '₹19,999',
#  '₹34,499',
#  '₹34,499',
#  '₹19,990',
#  '₹19,949',
#  '₹19,699',
#  '₹33,869',
#  '₹33,860',
#  '₹28,999',
#  '₹33,999',
#  '₹24,999',
#  '₹29,999',
#  '₹27,999',
#  '₹29,999']

# %%
#scraping Brand Name

name_brand = []

for b1 in ph[0:24]:
    driver.get(b1)
    time.sleep(2)
    
    try:
        read = driver.find_element(By.XPATH,'//span[@class="_3IIjhd"]')
        read.click()
        b2 = driver.find_element(By.XPATH,'//*[@id="container"]/div/div[1]/div/section/div/section/div[1]/div/div[1]')
        name_brand.append(b2.text)
    except NoSuchElementException:
        name_brand.append('-')

# %%
name_brand
# Out:
# ['OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus',
#  'OnePlus']

# %%
# Creating Data Frame

df = pd.DataFrame({"Brand":name_brand,"Smartphone Name":smart,"Colour":colour,"RAM":ram,"Storage":storage,"Primary/Secondary Camera":p_cam,"Display Size":display,"Battery Capacity":battery,"Price":price,"Product URL":ph})
df
# Out:
#       Brand                                    Smartphone Name        Colour  \
# 0   OnePlus  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...     Blue Tide
# 1   OnePlus  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...     Blue Tide
# 2   OnePlus  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...     Blue Tide
# 3   OnePlus  OnePlus Nord 2T 5G (Jade Fog, 128 GB)  (8 GB RAM)      Jade Fog
# 4   OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...    Black Dusk
# 5   OnePlus  OnePlus Nord CE 2 Lite (Black Dusk, 128 MB)  (...    Black Dusk
# 6   OnePlus  OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)  (8...   Bahama Blue
# 7   OnePlus  OnePlus Nord CE 5G (Charcoal Ink, 128 GB)  (6 ...  Charcoal Ink
# 8   OnePlus   OnePlus Nord 2 5G (PAC-MAN, 256 GB)  (12 GB RAM)       PAC-MAN
# 9   OnePlus  OnePlus Nord 2T 5G (Jade Fog, 256 GB)  (12 GB ...      Jade Fog
# 10  OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...    Black Dusk
# ...

# %%
df.to_csv('smartphone.csv')

# %%
pd.read_csv('smartphone.csv')
# Out:
#     Unnamed: 0    Brand                                    Smartphone Name  \
# 0            0  OnePlus  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...
# 1            1  OnePlus  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...
# 2            2  OnePlus  OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...
# 3            3  OnePlus  OnePlus Nord 2T 5G (Jade Fog, 128 GB)  (8 GB RAM)
# 4            4  OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...
# 5            5  OnePlus  OnePlus Nord CE 2 Lite (Black Dusk, 128 MB)  (...
# 6            6  OnePlus  OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)  (8...
# 7            7  OnePlus  OnePlus Nord CE 5G (Charcoal Ink, 128 GB)  (6 ...
# 8            8  OnePlus   OnePlus Nord 2 5G (PAC-MAN, 256 GB)  (12 GB RAM)
# 9            9  OnePlus  OnePlus Nord 2T 5G (Jade Fog, 256 GB)  (12 GB ...
# 10          10  OnePlus  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...
# ...

# %% [markdown]
# # Q5. Scrap Geospatial Coordinates (latitude, longitude) of a City

# %%
# connecting to webdriver

driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Searching webpage

driver.get("https://www.google.co.in/maps")

# %%
# Searching City

item = driver.find_element(By.XPATH,'//input[@class="searchboxinput xiQnY"]')
item.send_keys("Chennai")

search = driver.find_element(By.XPATH,'//button[@class="mL3xi"]')
search.click()

# %%
url_string = driver.current_url
print("URL Extracted: ", url_string)
# Out:
# URL Extracted:  https://www.google.co.in/maps/place/Chennai,+Tamil+Nadu/@13.0474878,80.0689241,11z/data=!4m5!3m4!1s0x3a5265ea4f7d3361:0x6e61a70b6863d433!8m2!3d13.0826802!4d80.2707184

# %%
latitude=url_string.split('@')[1].split(',')[0]
latitude
# Out:
# '13.0474878'

# %%
longitude=url_string.split('@')[1].split(',')[1]
longitude
# Out:
# '80.0689241'

# %%
print("Latitude Coordinates of Chennai  = ",latitude)
print("Longitude Coordinates of Chennai = ",longitude)
# Out:
# Latitude Coordinates of Chennai  =  13.0474878
# Longitude Coordinates of Chennai =  80.0689241

# %% [markdown]
# # Q6. Scrap details of all the funding deals for second quarter

# %%
#connecting to webdriver

driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Searching for webpage

driver.get("https://trak.in/india-startup-funding-investment-2015/")

# %%
# Scraping details for Date

date = []

dates = driver.find_elements(By.XPATH,'//td[@class="column-2"]')
for date1 in dates[5:29]:
    date.append(date1.text)

# %%
# Scraping details for startup Name

startup = []

start = driver.find_elements(By.XPATH,'//td[@class="column-3"]')
for i in start[5:29]:
    startup.append(i.text)

# %%
# Scraping details for industry

industry = []

ind = driver.find_elements(By.XPATH,'//td[@class="column-4"]')
for inver in ind[5:29]:
    industry.append(inver.text)

# %%
# Scraping details for Sub vertical

sub_vertical = []

sub = driver.find_elements(By.XPATH,'//td[@class="column-5"]')
for subv in sub[5:29]:
    sub_vertical.append(subv.text)

# %%
# Scraping details for City

city = []

location = driver.find_elements(By.XPATH,'//td[@class="column-6"]')
for city1 in location[5:29]:
    city.append(city1.text)

# %%
# Scraping details for Investor

investor = []

invest = driver.find_elements(By.XPATH,'//td[@class="column-7"]')
for invest1 in invest[5:29]:
    investor.append(invest1.text)

# %%
# Scraping details for Investment type

investment = []

investment1 = driver.find_elements(By.XPATH,'//td[@class="column-8"]')
for investment2 in investment1[5:29]:
    investment.append(investment2.text)

# %%
# Scraping details for amount

amount = []

amount1 = driver.find_elements(By.XPATH,'//td[@class="column-9"]')
for amount3 in amount1[5:29]:
    amount.append(amount3.text)

# %%
# Creating Data Frame

df = pd.DataFrame({"Date":date,"Startup Name":startup,"Industry":industry,"Sub_Vertical":sub_vertical,"City/Location":city,"Investor's Name":investor,"Investment Type":investment,"Amount(In USD)":amount})
df
# Out:
#           Date            Startup Name                Industry  \
# 0   31/03/2021                Uniphore              Technology
# 1   30/03/2021                   Dunzo              E-commerce
# 2   30/03/2021                  BYJU’S                Edu-tech
# 3   26/03/2021                   DotPe                 FinTech
# 4   25/03/2021                CityMall              E-commerce
# 5   23/03/2021             SkilloVilla                Edu-tech
# 6   04/03/2021               DealShare              E-commerce
# 7   22/02/2021                  Zomato             Hospitality
# 8   19/02/2021               Fingerlix             Hospitality
# 9   17/02/2021                   Zolve                 FinTech
# 10  15/02/2021               KreditBee                 Finance
# 11  12/02/2021               Pepperfry              E-commerce
# 12  12/02/2021                 Grofers              E-Commerce
# 13  11/02/2021                Doubtnut                Edu Tech
# ...

# %%
df.to_csv('Funding.csv')

# %%
pd.read_csv('Funding.csv')
# Out:
#     Unnamed: 0        Date            Startup Name                Industry  \
# 0            0  31/03/2021                Uniphore              Technology
# 1            1  30/03/2021                   Dunzo              E-commerce
# 2            2  30/03/2021                  BYJU’S                Edu-tech
# 3            3  26/03/2021                   DotPe                 FinTech
# 4            4  25/03/2021                CityMall              E-commerce
# 5            5  23/03/2021             SkilloVilla                Edu-tech
# 6            6  04/03/2021               DealShare              E-commerce
# 7            7  22/02/2021                  Zomato             Hospitality
# 8            8  19/02/2021               Fingerlix             Hospitality
# 9            9  17/02/2021                   Zolve                 FinTech
# 10          10  15/02/2021               KreditBee                 Finance
# ...

# %% [markdown]
# # Q7. Scrap all the available details of best gaming laptops

# %%
#connecting to webdriver

driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Searching for webpage
driver.get("https://www.digit.in/")

# %%
item = driver.find_element(By.XPATH,'/html/body/div[3]/div/div[2]/div[2]/div[4]/ul/li[9]/a')
item.click()

# %%
# Scraping details for Name

name = []

name1 = driver.find_elements(By.XPATH,'/html/body/div[5]/div[1]/div[3]/div[2]/div/div[1]/div[1]/a/h3')
for i in name1:
    name.append(i.text)

# %%
# Scraping details for Processor

processor = []

processor1 = driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
for i in processor1:
    processor.append(i.text)

# %%
# Scraping details for Display

display_laptop = []

dis1 = driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
for i in dis1:
    display_laptop.append(i.text)

# %%
# Scraping details for OS

os = []

os1 = driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
for i in os1:
    os.append(i.text)

# %%
# Scraping details for Memory

memory = []

memory1 = driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for i in memory1:
    memory.append(i.text)

# %%
# Scraping details for Graphic Processor

gp = []

gp1 = driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in gp1:
    gp.append(i.text)

# %%
# Scraping details for Body

body = []

body1 = driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in body1:
    body.append(i.text)

# %%
# Creating DataFrame

df = pd.DataFrame({"Laptop Name":name,"Processor":processor,"Display":display_laptop,"Operating System":os,"Memory":memory,"Graphic Processor":gp,"Body":body})
df
# Out:
#                                      Laptop Name  \
# 0                           MSI Titan GT77-12UHS
# 1                               Alienware X17 R2
# 2          Acer Predator Triton 500 SE PT516-52s
# 3                        Omen By HP (16-B1371TX)
# 4              Acer Predator Helios 300 AN515-45
# 5                     MSI Delta 15 (A5EFK-083IN)
# 6                        Omen By HP (16-C0141AX)
# 7              Lenovo Legion 5i Pro (82RF00MGIN)
# 8  Alienware M15 R5 Ryzen Edition Icc-C780001win
# 9               Lenovo Slim 7 Gen 6 (82K8002JIN)
#
#                                            Processor  \
# 0   12th Gen Intel Core i9-12900HX 16 core processor
# 1  12th Gen Intel Core i9-12900H 14 core processo...
# 2  12th Gen Intel Core i7-12700H 14 core processo...
# 3  12th Gen Intel Core i7-12700H 14 core processo...
# 4                AMD Ryzen 9-5900HX 8 core processor
# 5  AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# ...

# %%
df.to_csv('Laptop.csv')

# %%
pd.read_csv('laptop.csv')
# Out:
#    Unnamed: 0                                    Laptop Name  \
# 0           0                           MSI Titan GT77-12UHS
# 1           1                               Alienware X17 R2
# 2           2          Acer Predator Triton 500 SE PT516-52s
# 3           3                        Omen By HP (16-B1371TX)
# 4           4              Acer Predator Helios 300 AN515-45
# 5           5                     MSI Delta 15 (A5EFK-083IN)
# 6           6                        Omen By HP (16-C0141AX)
# 7           7              Lenovo Legion 5i Pro (82RF00MGIN)
# 8           8  Alienware M15 R5 Ryzen Edition Icc-C780001win
# 9           9               Lenovo Slim 7 Gen 6 (82K8002JIN)
#
#                                            Processor  \
# 0   12th Gen Intel Core i9-12900HX 16 core processor
# 1  12th Gen Intel Core i9-12900H 14 core processo...
# 2  12th Gen Intel Core i7-12700H 14 core processo...
# 3  12th Gen Intel Core i7-12700H 14 core processo...
# ...

# %% [markdown]
# # Q8. Scrape the details for all billionaires from Forbes

# %%
# Connecting to webdriver

driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Connecting to webpage

driver.get("http://www.forbes.com/")

# %%
#searching World Billionares

find = driver.find_element(By.XPATH,'//div[@id="globalHeaderMenu"]')
find.click()
time.sleep(2)

find2 = driver.find_element(By.XPATH,'//*[@id="globalHeaderMenu"]/div/div[2]/ul/li[1]/div[1]/a')
find2.click()
time.sleep(3)

find3 = driver.find_element(By.XPATH,'//*[@id="row-1"]/div/div/div[1]/div/div[1]/div[1]/div[2]/a')
find3.click()
time.sleep(2)

# %%
rank = []

for page in range(0,14):
    try:
        rank1 = driver.find_elements(By.XPATH,'//div[@class="rank"]')
        for i in rank1[0:200]:
            rank.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//button[@class="pagination-btn pagination-btn--next "]')
        nxt_button.click()
        time.sleep(5)
        
    except NoSuchElementException:
        first_button = driver.find_element(By.XPATH,'//button[@class="goto-page__btn"][1]')
        first_button.click()
        break
        
name_b = []

for page in range(0,14):
    try:
        name_b1 = driver.find_elements(By.XPATH,'//div[@class="personName"]')
        for i in name_b1[0:200]:
            name_b.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//button[@class="pagination-btn pagination-btn--next "]')
        nxt_button.click()
        time.sleep(5)
        
    except NoSuchElementException:
        first_button = driver.find_element(By.XPATH,'//button[@class="goto-page__btn"][1]')
        first_button.click()
        break

        
net = []

for page in range(0,14):
    try:
        net1 = driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
        for i in net1[0:200]:
            net.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//button[@class="pagination-btn pagination-btn--next "]')
        nxt_button.click()
        time.sleep(5)
        
    except NoSuchElementException:
        first_button = driver.find_element(By.XPATH,'//button[@class="goto-page__btn"][1]')
        first_button.click()
        break
      
    
age = []

for page in range(0,14):
    try:
        age1 = driver.find_elements(By.XPATH,'//div[@class="age"]')
        for i in age1[0:200]:
            age.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//button[@class="pagination-btn pagination-btn--next "]')
        nxt_button.click()
        time.sleep(5)
        
    except NoSuchElementException:
        first_button = driver.find_element(By.XPATH,'//button[@class="goto-page__btn"][1]')
        first_button.click()
        break
        

citizen = []

for page in range(0,14):
    try:
        citizen1 = driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
        for i in citizen1[0:200]:
            citizen.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//button[@class="pagination-btn pagination-btn--next "]')
        nxt_button.click()
        time.sleep(5)
        
    except NoSuchElementException:
        first_button = driver.find_element(By.XPATH,'//button[@class="goto-page__btn"][1]')
        first_button.click()
        break


industry = []

for page in range(0,14):
    try:
        inds = driver.find_elements(By.XPATH,'//div[@class="category"]')
        for i in inds:
            industry.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//button[@class="pagination-btn pagination-btn--next "]')
        nxt_button.click()
        
    except NoSuchElementException:
        first_button = driver.find_element(By.XPATH,'//button[@class="goto-page__btn"][1]')
        first_button.click()
        break
        
source = []

for page in range(0,14):
    try:
        s1 = driver.find_elements(By.XPATH,'//span[@class="source-text"]')
        for i in s1:
            source.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//button[@class="pagination-btn pagination-btn--next "]')
        nxt_button.click()
        
    except NoSuchElementException:
        first_button = driver.find_element(By.XPATH,'//button[@class="goto-page__btn"][1]')
        first_button.click()
        break

# %%
#creating Data Frame

df = pd.DataFrame({"Rank":rank,"Name":name_b,"Net Worth":net,"Age":age,"Citizenship":citizen,"Source":source,"Industry":industry})
df
# Out:
#        Rank                      Name Net Worth Age    Citizenship  \
# 0        1.                 Elon Musk    $219 B  50  United States
# 1        2.                Jeff Bezos    $171 B  58  United States
# 2        3.  Bernard Arnault & family    $158 B  73         France
# 3        4.                Bill Gates    $129 B  66  United States
# 4        5.            Warren Buffett    $118 B  91  United States
# ...     ...                       ...       ...  ..            ...
# 2663  2578.             Zhang Yuqiang      $1 B  66          China
# 2664  2578.                Zhou Ruxin      $1 B  59          China
# 2665  2578.         Wen Zhou & family      $1 B  57          China
# 2666  2578.      Zhou Yifeng & family      $1 B  43          China
# 2667  2578.   Zhuang Kuilong & family      $1 B  59          China
#
#                        Source               Industry
# 0               Tesla, SpaceX             Automotive
# 1                      Amazon             Technology
# ...

# %%
df.to_csv('Billionaires.csv')

# %%
pd.read_csv('Billionaires.csv')
# Out:
#       Unnamed: 0    Rank                      Name Net Worth   Age  \
# 0              0     1.0                 Elon Musk    $219 B  50.0
# 1              1     2.0                Jeff Bezos    $171 B  58.0
# 2              2     3.0  Bernard Arnault & family    $158 B  73.0
# 3              3     4.0                Bill Gates    $129 B  66.0
# 4              4     5.0            Warren Buffett    $118 B  91.0
# ...          ...     ...                       ...       ...   ...
# 2663        2663  2578.0             Zhang Yuqiang      $1 B  66.0
# 2664        2664  2578.0                Zhou Ruxin      $1 B  59.0
# 2665        2665  2578.0         Wen Zhou & family      $1 B  57.0
# 2666        2666  2578.0      Zhou Yifeng & family      $1 B  43.0
# 2667        2667  2578.0   Zhuang Kuilong & family      $1 B  59.0
#
#         Citizenship                   Source               Industry
# 0     United States            Tesla, SpaceX             Automotive
# ...

# %% [markdown]
# # Q9. Program to extract Comments from You Tube

# %%
# Connecting to webdriver

driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Connecting to Webpage

driver.get("https://www.youtube.com/")

# %%
# Searching videos

video = driver.find_element(By.XPATH,'//input[@id="search"]')
video.send_keys("Thee Thalapathy")
time.sleep(5)

search = driver.find_element(By.XPATH,'//button[@id="search-icon-legacy"]')
search.click()
time.sleep(5)

search = driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-search/div[1]/ytd-two-column-search-results-renderer/div[2]/div/ytd-section-list-renderer/div[2]/ytd-item-section-renderer[1]/div[3]/ytd-video-renderer[1]/div[1]/div/div[1]/div/h3/a/yt-formatted-string')
search.click()
time.sleep(5)

# %%
# Scraping for comments

for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")
    time.sleep(2)

# %%
comment2 = []

comment = driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')

for comment1 in comment[0:550]:
    comment2.append(comment1.text)
    
comment4 = []
for i in range(len(comment2)):
    if i==len(comment2)-551:
        break
    else:
        comm3 = comment2[i].strip().split("\n")
    comment4.append(comm3)

# %%
# Scraping for Upvotes 

votes = []

vote = driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')

for vote1 in vote[0:550]:
    votes.append(vote1.text)

# %%
# Scraping for Upvotes 

time = []

time1 = driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')

for time2 in time1[0:550]:
    time.append(time2.text)

# %%
# Creating DataFrame

df = pd.DataFrame({"You Tube Comments":comment4,"Comment Upvotes":votes,"Time Posted":time})
df
# Out:
#                                      You Tube Comments Comment Upvotes  \
# 0                      [All Hail to "Thee Thalapathy"]             47K
# 1    [He is a singer, , He is a dancer, , He is a a...             19K
# 2                     [STR Voice+Thalapathi gossbumbs]             746
# 3          [Not only tamil fans but all Indians loves]            1.4K
# 4                                 [Always STR mass️️️]              70
# ..                                                 ...             ...
# 545        [Powerful people came from powerful places]
# 546                                         [STR mass]
# 547  [You have no idea how good it feels being a Ta...             342
# 548  [Thaman Music Totally Giving More Goosebumps S...               2
# 549                        [Varisu will smash records]
#
#              Time Posted
# 0            3 weeks ago
# 1            3 weeks ago
# 2             8 days ago
# 3    8 days ago (edited)
# 4              1 day ago
# ...

# %%
df.to_csv('YouTube.csv')

# %%
pd.read_csv('YouTube.csv')
# Out:
#      Unnamed: 0                                  You Tube Comments  \
# 0             0                  ['All Hail to "Thee Thalapathy"']
# 1             1  ['He is a singer', '', 'He is a dancer', '', '...
# 2             2                 ['STR Voice+Thalapathi gossbumbs']
# 3             3      ['Not only tamil fans but all Indians loves']
# 4             4                             ['Always STR mass️️️']
# ..          ...                                                ...
# 545         545      ['Powerful people came from powerful places']
# 546         546                                       ['STR mass']
# 547         547  ['You have no idea how good it feels being a T...
# 548         548  ['Thaman Music Totally Giving More Goosebumps ...
# 549         549                      ['Varisu will smash records']
#
#     Comment Upvotes          Time Posted
# 0               47K          3 weeks ago
# 1               19K          3 weeks ago
# ...

# %% [markdown]
# # Q10. Python program to scrape a data for all available Hostels from HostelWorld

# %%
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException

# %%
# Connecting to webdriver

driver = webdriver.Chrome(r"C:\Users\navee\Downloads\chromedriver_win32\chromedriver.exe")

# %%
# Connecting to webpage

driver.get("http://www.hostelworld.com/")

# %%
# Searching for Location

try:
    location = driver.find_element(By.XPATH,'//input[@class="search-input"]')
    location.send_keys("London")
    time.sleep(5)
except NoSuchElementException:
    location = driver.find_element(By.XPATH,'//input[@class="search-input"]')
    location.send_keys("London")
    time.sleep(5)

location2 = driver.find_element(By.XPATH,'//*[@id="predicted-search-results"]/li[2]/div/span')
location2.click()
time.sleep(2)

go = driver.find_element(By.XPATH,'//button[@id="search-button"]')
go.click()

# %%
# Scraping Hostel Name

hostel_name = []

for page in range(0,2):
    try:
        name = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
        for name1 in name[0:30]:
            hostel_name.append(name1.text)
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()  
    except NoSuchElementException:
        hostel_name.append('-')
        driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-27&to=2022-12-30&guests=2&page=1")
        break

# %%
# Scraping Distance

distance = []

for page in range(0,2):
    try:
        distance1 = driver.find_elements(By.XPATH,'//span[@class="description"]')
        for i in distance1[0:30]:
            distance.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()  
    except NoSuchElementException:
        distance.append('-')
        driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-27&to=2022-12-30&guests=2&page=1")
        break

# %%
# Scraping Ratings

rating = []

for page in range(0,2):
    try:
        rating1 = driver.find_elements(By.XPATH,'//*[@id="__layout"]/div/div[2]/div[4]/div/div/div/div[3]/div[2]/div[2]/a/div/div[1]')
        for i in rating1[0:30]:
            rating.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()  
    except NoSuchElementException:
        rating.append('-')
        driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-27&to=2022-12-30&guests=2&page=1")
        break

# %%
# Removing (/n) values

ratings = []
for i in range(len(rating)):
    if i==len(rating)-50:
        break
    else:
        rat = rating[i].strip().split("\n")
    ratings.append(rat)

# %%
# Scraping Total Reviews

reviews = []

for page in range(0,2):
    try:
        review = driver.find_elements(By.XPATH,'//div[@class="reviews"]')
        for i in review[0:30]:
            reviews.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()  
    except NoSuchElementException:
        reviews.append('-')
        driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-27&to=2022-12-30&guests=2&page=1")
        break

# %%
# Scraping Privates From Price

private = []

for page in range(0,2):
    try:
        privates = driver.find_elements(By.XPATH,'//div[@class="price-col"][1]')
        for i in privates[0:30]:
            private.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()  
    except NoSuchElementException:
        private.append('-')
        driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-27&to=2022-12-30&guests=2&page=1")
        break

# %%
# Removing (/n) values

private2 = []
for i in range(len(private)):
    if i==len(private)-50:
        break
    else:
        private3 = private[i].strip().split("\n")
    private2.append(private3)

# %%
# Scraping Dorms From Price

dorms = []

for page in range(0,2):
    try:
        dorm = driver.find_elements(By.XPATH,'//div[@class="price-col"][2]')
        for i in dorm[0:30]:
            dorms.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()  
    except NoSuchElementException:
        dorms.append('-')
        driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-27&to=2022-12-30&guests=2&page=1")
        break

dorm2 = []
for i in range(len(dorms)):
    if i==len(dorms)-50:
        break
    else:
        dorm3 = dorms[i].strip().split("\n")
    dorm2.append(dorm3)

# %%
# Scraping Overall Reviews

overall = []

for page in range(0,2):
    try:
        overallr = driver.find_elements(By.XPATH,'//div[@class="rating rating-summary-container big"]')
        for i in overallr[0:30]:
            overall.append(i.text)
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-last"]')
        nxt_button.click()  
    except NoSuchElementException:
        overall.append('-')
        driver.get("https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-12-27&to=2022-12-30&guests=2&page=1")
        break

# %%
# Unable to Scrape data for Description even after multiple times 

description = []

for urls in url[5:7]:
    driver.get(urls)
    time.sleep(2)


    try:
        button = driver.find_element(By.XPATH,'//a[@class="toggle-content"]')
        button.click()
 
    except NoSuchElementException:
        descriptions = driver.find_element(By.XPATH,'//div[@class="description-container"]')
        description.append(descriptions.text)
        
    try:
        nxt_button = driver.find_element(By.XPATH,'//a[@class="toggle-content"]')
        nxt_button.click()
    except ElementClickInterceptedException:
        nxt_button = driver.find_element(By.XPATH,'//a[@class="toggle-content"]')
        nxt_button.click()
            
    try:
        descriptions = driver.find_element(By.XPATH,'//div[@class="description-container"]')
        description.append(descriptions.text)
    except NoSuchElementException:
        description.append('-')
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Input In [972], in <cell line: 5>()
#      10 try:
#      11     button = driver.find_element(By.XPATH,'//a[@class="toggle-content"]')
# ---> 12     button.click()
#      14 except NoSuchElementException:
#      15     descriptions = driver.find_element(By.XPATH,'//div[@class="description-container"]')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:93, in WebElement.click(self)
#      91 def click(self) -> None:
#      92     """Clicks the element."""
# ---> 93     self._execute(Command.CLICK_ELEMENT)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:410, in WebElement._execute(self, command, params)
#     408     params = {}
#     409 params["id"] = self._id
# --> 410 return self._parent.execute(command, params)
#
# ...
